# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-04-02 11:55:10.250875: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.11.1

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %% [markdown]
# # Chapter 13

# %% [markdown]
# ## 13.1 Creating windows of data
# ### 13.1.1 Exploring how deep learning models are trained for time series forecasting

# %%
fig, ax = plt.subplots()

for n in range(0,17,2):
    start = 24*n
    stop = 24*(n+1)
    ax.plot(train_df.traffic_volume[start:stop], marker='s', color='blue', label='input')
    ax.plot(train_df.traffic_volume[stop:2*stop], marker='x', color='red', label='label')
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

# plt.savefig('figures/CH13_F01_peixeiro.png', dpi=300)

# %% [markdown]
# ### 13.1.2 Implementing the `DataWindow` class

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %% [markdown]
# ## 13.2 Applying baseline models
# ### 13.2.1 Single-step baseline model

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume']) 
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %%
class Baseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return inputs
        
        elif isinstance(self.label_index, list):
            tensors = []
            for index in self.label_index:
                result = inputs[:, :, index]
                result = result[:, :, tf.newaxis]
                tensors.append(result)
            return tf.concat(tensors, axis=-1)
        
        result = inputs[:, :, self.label_index]
        return result[:,:,tf.newaxis]

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

baseline_last = Baseline(label_index=column_indices['traffic_volume'])

baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])
# Out:
# 2023-04-02 11:56:05.895087: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
column_indices
# Out:
# {'temp': 0, 'clouds_all': 1, 'traffic_volume': 2, 'day_sin': 3, 'day_cos': 4}

# %%
val_performance = {}
performance = {}

val_performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.val)
performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.test, verbose=0)
# Out:
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0133 - mean_absolute_error: 0.0831

# %%
wide_window.plot(baseline_last)

plt.savefig('figures/CH13_F09_peixeiro.png', dpi=300)

# %%
print(performance['Baseline - Last'][1])
# Out:
# 0.08128400146961212

# %% [markdown]
# ### 13.2.2 Multi-step baseline models

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %% [markdown]
# #### Predicting the last known value

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        if self.label_index is None:
            return tf.tile(inputs[:, -1:, :], [1, 24, 1])
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 24, 1])

# %%
ms_baseline_last = MultiStepLastBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance = {}
ms_performance = {}

ms_val_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.val)
ms_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 1s 2ms/step - loss: 0.1875 - mean_absolute_error: 0.3522

# %%
multi_window.plot(ms_baseline_last)

plt.savefig('figures/CH13_F10_peixeiro.png', dpi=300)

# %%
print(ms_performance['Baseline - Last'][1])
# Out:
# 0.3472607433795929

# %% [markdown]
# #### Repeating the input sequence

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index
        
    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %%
ms_baseline_repeat = RepeatBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.val)
ms_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 2ms/step - loss: 0.2065 - mean_absolute_error: 0.3473

# %%
multi_window.plot(ms_baseline_repeat)

plt.savefig('figures/CH13_F11_peixeiro.png', dpi=300)

# %%
print(ms_performance['Baseline - Repeat'][1])
# Out:
# 0.341277152299881

# %% [markdown]
# ### 13.2.3 Multi-output baseline model

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume']) 
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
print(column_indices['traffic_volume'])
print(column_indices['temp'])
# Out:
# 2
# 0

# %%
mo_baseline_last = Baseline(label_index=[0, 2])

mo_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

mo_val_performance = {}
mo_performance = {}

mo_val_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.val)
mo_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0482

# %%
mo_wide_window.plot(mo_baseline_last)

plt.savefig('figures/CH13_F12_peixeiro.png', dpi=300)

# %%
mo_wide_window.plot(model=mo_baseline_last, plot_col='temp')

plt.savefig('figures/CH13_F13_peixeiro.png', dpi=300)

# %%
print(mo_performance['Baseline - Last'][1])

# %% [markdown]
# # Chapter 14

# %% [markdown]
# ## 14.1 Implementing a linear model
# ### 14.1.1 Building a single-step linear model

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
linear = Sequential([
    Dense(units=1)
])

history = compile_and_fit(linear, single_step_window)

val_performance['Linear'] = linear.evaluate(single_step_window.val)
performance['Linear'] = linear.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 3ms/step - loss: 0.6780 - mean_absolute_error: 0.7244 - val_loss: 0.5178 - val_mean_absolute_error: 0.6329
# Epoch 2/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.3586 - mean_absolute_error: 0.5245 - val_loss: 0.2736 - val_mean_absolute_error: 0.4553
# Epoch 3/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.1825 - mean_absolute_error: 0.3695 - val_loss: 0.1349 - val_mean_absolute_error: 0.3154
# Epoch 4/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0867 - mean_absolute_error: 0.2498 - val_loss: 0.0635 - val_mean_absolute_error: 0.2107
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0411 - mean_absolute_error: 0.1655 - val_loss: 0.0320 - val_mean_absolute_error: 0.1409
# Epoch 6/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0229 - mean_absolute_error: 0.1165 - val_loss: 0.0203 - val_mean_absolute_error: 0.1042
# Epoch 7/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0169 - mean_absolute_error: 0.0970 - val_loss: 0.0163 - val_mean_absolute_error: 0.0913
# Epoch 8/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.0910 - val_loss: 0.0147 - val_mean_absolute_error: 0.0869
# Epoch 9/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0139 - mean_absolute_error: 0.0876 - val_loss: 0.0137 - val_mean_absolute_error: 0.0828
# Epoch 10/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.0848 - val_loss: 0.0128 - val_mean_absolute_error: 0.0799
# Epoch 11/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.0820 - val_loss: 0.0120 - val_mean_absolute_error: 0.0763
# Epoch 12/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0792 - val_loss: 0.0113 - val_mean_absolute_error: 0.0738
# Epoch 13/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0110 - mean_absolute_error: 0.0767 - val_loss: 0.0108 - val_mean_absolute_error: 0.0709
# Epoch 14/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0105 - mean_absolute_error: 0.0745 - val_loss: 0.0102 - val_mean_absolute_error: 0.0693
# Epoch 15/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0101 - mean_absolute_error: 0.0726 - val_loss: 0.0099 - val_mean_absolute_error: 0.0677
# Epoch 16/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0098 - mean_absolute_error: 0.0712 - val_loss: 0.0097 - val_mean_absolute_error: 0.0653
# Epoch 17/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0701 - val_loss: 0.0094 - val_mean_absolute_error: 0.0654
# Epoch 18/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0095 - mean_absolute_error: 0.0693 - val_loss: 0.0093 - val_mean_absolute_error: 0.0655
# Epoch 19/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0688 - val_loss: 0.0092 - val_mean_absolute_error: 0.0652
# Epoch 20/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0684 - val_loss: 0.0092 - val_mean_absolute_error: 0.0649
# Epoch 21/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0681 - val_loss: 0.0091 - val_mean_absolute_error: 0.0646
# Epoch 22/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0680 - val_loss: 0.0091 - val_mean_absolute_error: 0.0653
# Epoch 23/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0648
# Epoch 24/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0653
# Epoch 25/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0646
# Epoch 26/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0654
# Epoch 27/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0645
# Epoch 28/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0639
# Epoch 29/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0655
# Epoch 30/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0648
# Epoch 31/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0677 - val_loss: 0.0091 - val_mean_absolute_error: 0.0644
# Epoch 32/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0678 - val_loss: 0.0091 - val_mean_absolute_error: 0.0639
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0091 - mean_absolute_error: 0.0639

# %%
wide_window.plot(linear)

plt.savefig('figures/CH14_F02_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.1.2 Building a mutli-step linear model

# %%
ms_linear = Sequential([
    Dense(1, kernel_initializer=tf.initializers.zeros)
])

history = compile_and_fit(ms_linear, multi_window)

ms_val_performance['Linear'] = ms_linear.evaluate(multi_window.val)
ms_performance['Linear'] = ms_linear.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0900 - mean_absolute_error: 0.2467 - val_loss: 0.0458 - val_mean_absolute_error: 0.1822
# Epoch 2/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0298 - mean_absolute_error: 0.1369 - val_loss: 0.0261 - val_mean_absolute_error: 0.1253
# Epoch 3/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0201 - mean_absolute_error: 0.1045 - val_loss: 0.0212 - val_mean_absolute_error: 0.1073
# Epoch 4/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0177 - mean_absolute_error: 0.0955 - val_loss: 0.0196 - val_mean_absolute_error: 0.0999
# Epoch 5/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0168 - mean_absolute_error: 0.0914 - val_loss: 0.0188 - val_mean_absolute_error: 0.0953
# Epoch 6/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0887 - val_loss: 0.0184 - val_mean_absolute_error: 0.0925
# Epoch 7/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0162 - mean_absolute_error: 0.0869 - val_loss: 0.0183 - val_mean_absolute_error: 0.0903
# Epoch 8/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0162 - mean_absolute_error: 0.0857 - val_loss: 0.0182 - val_mean_absolute_error: 0.0893
# Epoch 9/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_absolute_error: 0.0850 - val_loss: 0.0182 - val_mean_absolute_error: 0.0888
# Epoch 10/50
# 383/383 [==============================] - 1s 2ms/step - loss: 0.0161 - mean_absolute_error: 0.0846 - val_loss: 0.0181 - val_mean_absolute_error: 0.0885
# Epoch 11/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0843 - val_loss: 0.0181 - val_mean_absolute_error: 0.0882
# Epoch 12/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0841 - val_loss: 0.0182 - val_mean_absolute_error: 0.0880
# Epoch 13/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0840 - val_loss: 0.0182 - val_mean_absolute_error: 0.0881
# Epoch 14/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0161 - mean_absolute_error: 0.0839 - val_loss: 0.0182 - val_mean_absolute_error: 0.0881
# 109/109 [==============================] - 0s 2ms/step - loss: 0.0182 - mean_absolute_error: 0.0881

# %% [markdown]
# ### 14.1.3 Implementing a multi-output linear model

# %%
mo_linear = Sequential([
    Dense(units=2)
])

history = compile_and_fit(mo_linear, mo_single_step_window)

mo_val_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.val)
mo_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0965 - mean_absolute_error: 0.2279 - val_loss: 0.0717 - val_mean_absolute_error: 0.2010
# Epoch 2/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0467 - mean_absolute_error: 0.1604 - val_loss: 0.0404 - val_mean_absolute_error: 0.1534
# Epoch 3/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0293 - mean_absolute_error: 0.1285 - val_loss: 0.0266 - val_mean_absolute_error: 0.1258
# Epoch 4/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0207 - mean_absolute_error: 0.1087 - val_loss: 0.0188 - val_mean_absolute_error: 0.1064
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0152 - mean_absolute_error: 0.0939 - val_loss: 0.0137 - val_mean_absolute_error: 0.0907
# Epoch 6/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0112 - mean_absolute_error: 0.0811 - val_loss: 0.0100 - val_mean_absolute_error: 0.0779
# Epoch 7/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0697 - val_loss: 0.0075 - val_mean_absolute_error: 0.0661
# Epoch 8/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0599 - val_loss: 0.0060 - val_mean_absolute_error: 0.0561
# Epoch 9/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0521 - val_loss: 0.0052 - val_mean_absolute_error: 0.0486
# Epoch 10/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0052 - mean_absolute_error: 0.0464 - val_loss: 0.0049 - val_mean_absolute_error: 0.0431
# Epoch 11/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0428 - val_loss: 0.0047 - val_mean_absolute_error: 0.0403
# Epoch 12/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0050 - mean_absolute_error: 0.0408 - val_loss: 0.0047 - val_mean_absolute_error: 0.0386
# Epoch 13/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0400 - val_loss: 0.0047 - val_mean_absolute_error: 0.0381
# Epoch 14/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0397 - val_loss: 0.0047 - val_mean_absolute_error: 0.0377
# Epoch 15/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0377
# Epoch 16/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0379
# Epoch 17/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0373
# Epoch 18/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0379
# Epoch 19/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0376
# Epoch 20/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0378
# Epoch 21/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0376
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_absolute_error: 0.0376

# %% [markdown]
# ## 14.2 Implementing a deep neural network
# ### 14.2.1 Implementing a deep neural network as a single-step model

# %%
dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(dense, single_step_window)

val_performance['Dense'] = dense.evaluate(single_step_window.val)
performance['Dense'] = dense.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.0845 - val_loss: 0.0049 - val_mean_absolute_error: 0.0528
# Epoch 2/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0489 - val_loss: 0.0036 - val_mean_absolute_error: 0.0449
# Epoch 3/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0037 - mean_absolute_error: 0.0446 - val_loss: 0.0030 - val_mean_absolute_error: 0.0402
# Epoch 4/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0034 - mean_absolute_error: 0.0421 - val_loss: 0.0035 - val_mean_absolute_error: 0.0444
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0032 - mean_absolute_error: 0.0408 - val_loss: 0.0031 - val_mean_absolute_error: 0.0418
# Epoch 6/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0031 - mean_absolute_error: 0.0400 - val_loss: 0.0026 - val_mean_absolute_error: 0.0382
# Epoch 7/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - val_loss: 0.0023 - val_mean_absolute_error: 0.0356
# Epoch 8/50
# 384/384 [==============================] - 1s 3ms/step - loss: 0.0028 - mean_absolute_error: 0.0378 - val_loss: 0.0029 - val_mean_absolute_error: 0.0412
# Epoch 9/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0373 - val_loss: 0.0032 - val_mean_absolute_error: 0.0429
# Epoch 10/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0027 - mean_absolute_error: 0.0369 - val_loss: 0.0022 - val_mean_absolute_error: 0.0348
# Epoch 11/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0361 - val_loss: 0.0023 - val_mean_absolute_error: 0.0345
# Epoch 12/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0356 - val_loss: 0.0021 - val_mean_absolute_error: 0.0328
# Epoch 13/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0354 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 14/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0350 - val_loss: 0.0027 - val_mean_absolute_error: 0.0386
# Epoch 15/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0349 - val_loss: 0.0024 - val_mean_absolute_error: 0.0362
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0024 - mean_absolute_error: 0.0362

# %%
wide_window.plot(dense)

plt.savefig('figures/CH14_F06_peixeiro.png', dpi=300)

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.2.2 Implementing a deep neural network as a multi-step model

# %%
ms_dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_dense, multi_window)

ms_val_performance['Dense'] = ms_dense.evaluate(multi_window.val)
ms_performance['Dense'] = ms_dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 2s 4ms/step - loss: 0.0308 - mean_absolute_error: 0.1111 - val_loss: 0.0164 - val_mean_absolute_error: 0.0823
# Epoch 2/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0784 - val_loss: 0.0161 - val_mean_absolute_error: 0.0815
# Epoch 3/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0772 - val_loss: 0.0154 - val_mean_absolute_error: 0.0849
# Epoch 4/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0772 - val_loss: 0.0150 - val_mean_absolute_error: 0.0832
# Epoch 5/50
# 383/383 [==============================] - 1s 3ms/step - loss: 0.0131 - mean_absolute_error: 0.0763 - val_loss: 0.0149 - val_mean_absolute_error: 0.0774
# Epoch 6/50
# 383/383 [==============================] - 1s 4ms/step - loss: 0.0130 - mean_absolute_error: 0.0762 - val_loss: 0.0148 - val_mean_absolute_error: 0.0774
# Epoch 7/50
# 383/383 [==============================] - 2s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0756 - val_loss: 0.0148 - val_mean_absolute_error: 0.0807
# Epoch 8/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0757 - val_loss: 0.0147 - val_mean_absolute_error: 0.0806
# Epoch 9/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0752 - val_loss: 0.0146 - val_mean_absolute_error: 0.0812
# Epoch 10/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0750 - val_loss: 0.0145 - val_mean_absolute_error: 0.0780
# Epoch 11/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0752 - val_loss: 0.0148 - val_mean_absolute_error: 0.0812
# Epoch 12/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0127 - mean_absolute_error: 0.0752 - val_loss: 0.0148 - val_mean_absolute_error: 0.0806
# Epoch 13/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0126 - mean_absolute_error: 0.0747 - val_loss: 0.0144 - val_mean_absolute_error: 0.0787
# Epoch 14/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0126 - mean_absolute_error: 0.0745 - val_loss: 0.0147 - val_mean_absolute_error: 0.0787
# Epoch 15/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0744 - val_loss: 0.0146 - val_mean_absolute_error: 0.0778
# Epoch 16/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0746 - val_loss: 0.0147 - val_mean_absolute_error: 0.0755
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0147 - mean_absolute_error: 0.0755

# %%
ms_mae_val = [v[1] for v in ms_val_performance.values()]
ms_mae_test = [v[1] for v in ms_performance.values()]

x = np.arange(len(ms_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=ms_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F08_peixeiro.png', dpi=300)

# %% [markdown]
# ### 14.2.3 Implementing a deep neural network as a multi-output model

# %%
mo_dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_dense, mo_single_step_window)

mo_val_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.val)
mo_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.test, verbose=0)

# %%
mo_mae_val = [v[1] for v in mo_val_performance.values()]
mo_mae_test = [v[1] for v in mo_performance.values()]

x = np.arange(len(mo_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=mo_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH14_F09_peixeiro.png', dpi=300)
