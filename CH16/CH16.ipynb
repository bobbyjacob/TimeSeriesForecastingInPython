# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-04-02 17:11:14.542844: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.11.1

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## CNN

# %% [markdown]
# ### Single-step model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

conv_window = DataWindow(input_width=KERNEL_WIDTH, label_width=1, shift=1, label_columns=['traffic_volume'])
wide_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=1, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 15

mae_val = [0.083, 0.068, 0.033, 0.03]
mae_test = [0.081, 0.068, 0.029, 0.026]

# %%
cnn_model = Sequential([
    Conv1D(filters=32,
          kernel_size=(KERNEL_WIDTH,),
          activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(cnn_model, conv_window)

val_performance = {}
performance = {}

val_performance['CNN'] = cnn_model.evaluate(conv_window.val)
performance['CNN'] = cnn_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 2023-04-02 17:11:16.046728: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 384/384 [==============================] - 2s 3ms/step - loss: 0.0264 - mean_absolute_error: 0.1078 - val_loss: 0.0077 - val_mean_absolute_error: 0.0632
# Epoch 2/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0593 - val_loss: 0.0055 - val_mean_absolute_error: 0.0556
# Epoch 3/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0049 - mean_absolute_error: 0.0508 - val_loss: 0.0039 - val_mean_absolute_error: 0.0460
# Epoch 4/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0040 - mean_absolute_error: 0.0463 - val_loss: 0.0032 - val_mean_absolute_error: 0.0411
# Epoch 5/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0426 - val_loss: 0.0026 - val_mean_absolute_error: 0.0379
# Epoch 6/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0030 - mean_absolute_error: 0.0396 - val_loss: 0.0023 - val_mean_absolute_error: 0.0360
# Epoch 7/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0029 - mean_absolute_error: 0.0386 - val_loss: 0.0026 - val_mean_absolute_error: 0.0380
# Epoch 8/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_error: 0.0381 - val_loss: 0.0024 - val_mean_absolute_error: 0.0362
# Epoch 9/50
# 384/384 [==============================] - 1s 2ms/step - loss: 0.0026 - mean_absolute_error: 0.0367 - val_loss: 0.0023 - val_mean_absolute_error: 0.0348
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0023 - mean_absolute_error: 0.0348

# %%
wide_conv_window.plot(cnn_model)

plt.savefig('figures/CH16_F05_peixeiro.png', dpi=300)

# %% [markdown]
# #### CNN + LSTM

# %%
cnn_lstm_model = Sequential([
    Conv1D(filters=32,
          kernel_size=(KERNEL_WIDTH,),
          activation='relu'),
    LSTM(32, return_sequences=True),
    LSTM(32, return_sequences=True),
    Dense(1)
])

history = compile_and_fit(cnn_lstm_model, conv_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 7s 9ms/step - loss: 0.0308 - mean_absolute_error: 0.1164 - val_loss: 0.0073 - val_mean_absolute_error: 0.0650
# Epoch 2/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0059 - mean_absolute_error: 0.0562 - val_loss: 0.0044 - val_mean_absolute_error: 0.0487
# Epoch 3/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0044 - mean_absolute_error: 0.0481 - val_loss: 0.0036 - val_mean_absolute_error: 0.0437
# Epoch 4/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0038 - mean_absolute_error: 0.0447 - val_loss: 0.0030 - val_mean_absolute_error: 0.0415
# Epoch 5/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0420 - val_loss: 0.0030 - val_mean_absolute_error: 0.0402
# Epoch 6/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0032 - mean_absolute_error: 0.0404 - val_loss: 0.0035 - val_mean_absolute_error: 0.0463
# Epoch 7/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0032 - mean_absolute_error: 0.0404 - val_loss: 0.0025 - val_mean_absolute_error: 0.0373
# Epoch 8/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0030 - mean_absolute_error: 0.0394 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 9/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0030 - mean_absolute_error: 0.0392 - val_loss: 0.0024 - val_mean_absolute_error: 0.0359
# Epoch 10/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0030 - mean_absolute_error: 0.0394 - val_loss: 0.0024 - val_mean_absolute_error: 0.0364
# Epoch 11/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0029 - mean_absolute_error: 0.0382 - val_loss: 0.0029 - val_mean_absolute_error: 0.0409
# Epoch 12/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0028 - mean_absolute_error: 0.0378 - val_loss: 0.0023 - val_mean_absolute_error: 0.0355
# Epoch 13/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0028 - mean_absolute_error: 0.0373 - val_loss: 0.0022 - val_mean_absolute_error: 0.0343
# Epoch 14/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0027 - mean_absolute_error: 0.0367 - val_loss: 0.0024 - val_mean_absolute_error: 0.0369
# Epoch 15/50
# 384/384 [==============================] - 3s 9ms/step - loss: 0.0027 - mean_absolute_error: 0.0365 - val_loss: 0.0022 - val_mean_absolute_error: 0.0349
# Epoch 16/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0027 - mean_absolute_error: 0.0367 - val_loss: 0.0044 - val_mean_absolute_error: 0.0550
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0044 - mean_absolute_error: 0.0550

# %%
mae_val.extend([v[1] for v in val_performance.values()])
mae_test.extend([v[1] for v in performance.values()])

x = np.arange(6)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH16_F06_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-step model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, shift=24, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 15

ms_mae_val = [0.352, 0.347, 0.088, 0.078, 0.070]
ms_mae_test = [0.347, 0.341, 0.076, 0.064, 0.058]

# %%
ms_cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_cnn_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['CNN'] = ms_cnn_model.evaluate(multi_window.val)
ms_performance['CNN'] = ms_cnn_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 3s 5ms/step - loss: 0.0373 - mean_absolute_error: 0.1286 - val_loss: 0.0162 - val_mean_absolute_error: 0.0846
# Epoch 2/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0138 - mean_absolute_error: 0.0788 - val_loss: 0.0155 - val_mean_absolute_error: 0.0823
# Epoch 3/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0135 - mean_absolute_error: 0.0776 - val_loss: 0.0155 - val_mean_absolute_error: 0.0859
# Epoch 4/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0132 - mean_absolute_error: 0.0768 - val_loss: 0.0149 - val_mean_absolute_error: 0.0802
# Epoch 5/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0131 - mean_absolute_error: 0.0764 - val_loss: 0.0149 - val_mean_absolute_error: 0.0814
# Epoch 6/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0130 - mean_absolute_error: 0.0759 - val_loss: 0.0147 - val_mean_absolute_error: 0.0812
# Epoch 7/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0755 - val_loss: 0.0151 - val_mean_absolute_error: 0.0788
# Epoch 8/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0129 - mean_absolute_error: 0.0754 - val_loss: 0.0151 - val_mean_absolute_error: 0.0799
# Epoch 9/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0750 - val_loss: 0.0146 - val_mean_absolute_error: 0.0797
# Epoch 10/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0750 - val_loss: 0.0150 - val_mean_absolute_error: 0.0827
# Epoch 11/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0747 - val_loss: 0.0150 - val_mean_absolute_error: 0.0775
# Epoch 12/50
# 383/383 [==============================] - 2s 4ms/step - loss: 0.0127 - mean_absolute_error: 0.0744 - val_loss: 0.0146 - val_mean_absolute_error: 0.0794
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0794

# %% [markdown]
# #### CNN + LSTM

# %%
ms_cnn_lstm_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_cnn_lstm_model, multi_window)

ms_val_performance['CNN + LSTM'] = ms_cnn_lstm_model.evaluate(multi_window.val)
ms_performance['CNN + LSTM'] = ms_cnn_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 10s 21ms/step - loss: 0.0396 - mean_absolute_error: 0.1388 - val_loss: 0.0172 - val_mean_absolute_error: 0.0901
# Epoch 2/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0146 - mean_absolute_error: 0.0821 - val_loss: 0.0163 - val_mean_absolute_error: 0.0850
# Epoch 3/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0141 - mean_absolute_error: 0.0793 - val_loss: 0.0158 - val_mean_absolute_error: 0.0820
# Epoch 4/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0138 - mean_absolute_error: 0.0777 - val_loss: 0.0156 - val_mean_absolute_error: 0.0824
# Epoch 5/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0134 - mean_absolute_error: 0.0762 - val_loss: 0.0157 - val_mean_absolute_error: 0.0771
# Epoch 6/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0131 - mean_absolute_error: 0.0752 - val_loss: 0.0146 - val_mean_absolute_error: 0.0777
# Epoch 7/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0129 - mean_absolute_error: 0.0743 - val_loss: 0.0148 - val_mean_absolute_error: 0.0784
# Epoch 8/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0126 - mean_absolute_error: 0.0735 - val_loss: 0.0142 - val_mean_absolute_error: 0.0800
# Epoch 9/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0125 - mean_absolute_error: 0.0733 - val_loss: 0.0150 - val_mean_absolute_error: 0.0749
# Epoch 10/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0122 - mean_absolute_error: 0.0723 - val_loss: 0.0142 - val_mean_absolute_error: 0.0756
# Epoch 11/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0119 - mean_absolute_error: 0.0713 - val_loss: 0.0134 - val_mean_absolute_error: 0.0761
# Epoch 12/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0118 - mean_absolute_error: 0.0709 - val_loss: 0.0135 - val_mean_absolute_error: 0.0765
# Epoch 13/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0116 - mean_absolute_error: 0.0704 - val_loss: 0.0141 - val_mean_absolute_error: 0.0778
# Epoch 14/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0114 - mean_absolute_error: 0.0694 - val_loss: 0.0130 - val_mean_absolute_error: 0.0723
# Epoch 15/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0112 - mean_absolute_error: 0.0688 - val_loss: 0.0133 - val_mean_absolute_error: 0.0759
# Epoch 16/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0110 - mean_absolute_error: 0.0683 - val_loss: 0.0128 - val_mean_absolute_error: 0.0714
# Epoch 17/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0110 - mean_absolute_error: 0.0681 - val_loss: 0.0126 - val_mean_absolute_error: 0.0722
# Epoch 18/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0109 - mean_absolute_error: 0.0675 - val_loss: 0.0125 - val_mean_absolute_error: 0.0738
# Epoch 19/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0108 - mean_absolute_error: 0.0675 - val_loss: 0.0127 - val_mean_absolute_error: 0.0714
# Epoch 20/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0106 - mean_absolute_error: 0.0665 - val_loss: 0.0127 - val_mean_absolute_error: 0.0755
# Epoch 21/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0106 - mean_absolute_error: 0.0667 - val_loss: 0.0125 - val_mean_absolute_error: 0.0723
# 109/109 [==============================] - 1s 9ms/step - loss: 0.0125 - mean_absolute_error: 0.0723

# %%
ms_mae_val.extend([v[1] for v in ms_val_performance.values()])
ms_mae_test.extend([v[1] for v in ms_performance.values()])

x = np.arange(7)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH16_F07_peixeiro.png', dpi=300)

# %% [markdown]
# ### Multi-output model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

wide_mo_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=24, shift=1, label_columns=['temp', 'traffic_volume'])

# %%
# Values from chapter 15

mo_mae_val = [0.048, 0.039, 0.023, 0.020]
mo_mae_test = [0.047, 0.036, 0.020, 0.017]

# %%
mo_cnn_model = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_cnn_model, wide_mo_conv_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['CNN'] = mo_cnn_model.evaluate(wide_mo_conv_window.val)
mo_performance['CNN'] = mo_cnn_model.evaluate(wide_mo_conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 5ms/step - loss: 0.0215 - mean_absolute_error: 0.0767 - val_loss: 0.0027 - val_mean_absolute_error: 0.0333
# Epoch 2/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0318 - val_loss: 0.0020 - val_mean_absolute_error: 0.0290
# Epoch 3/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0286 - val_loss: 0.0016 - val_mean_absolute_error: 0.0265
# Epoch 4/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0018 - mean_absolute_error: 0.0266 - val_loss: 0.0014 - val_mean_absolute_error: 0.0253
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0014 - val_mean_absolute_error: 0.0247
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0249 - val_loss: 0.0013 - val_mean_absolute_error: 0.0240
# Epoch 7/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0243 - val_loss: 0.0013 - val_mean_absolute_error: 0.0237
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0239 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 9/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0236 - val_loss: 0.0012 - val_mean_absolute_error: 0.0230
# Epoch 10/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0233 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 11/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0231 - val_loss: 0.0012 - val_mean_absolute_error: 0.0233
# Epoch 12/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0228 - val_loss: 0.0011 - val_mean_absolute_error: 0.0219
# Epoch 13/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0227 - val_loss: 0.0015 - val_mean_absolute_error: 0.0263
# Epoch 14/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0225 - val_loss: 0.0011 - val_mean_absolute_error: 0.0218
# Epoch 15/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0225 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 16/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0221 - val_loss: 0.0012 - val_mean_absolute_error: 0.0224
# Epoch 17/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0220 - val_loss: 0.0011 - val_mean_absolute_error: 0.0216
# Epoch 18/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0210
# Epoch 19/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0218 - val_loss: 0.0015 - val_mean_absolute_error: 0.0251
# Epoch 20/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0216 - val_loss: 0.0010 - val_mean_absolute_error: 0.0207
# Epoch 21/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0215 - val_loss: 0.0013 - val_mean_absolute_error: 0.0237
# Epoch 22/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0013 - mean_absolute_error: 0.0215 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 23/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0211 - val_loss: 0.0010 - val_mean_absolute_error: 0.0206
# Epoch 24/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0209 - val_loss: 0.0010 - val_mean_absolute_error: 0.0206
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0209 - val_loss: 0.0010 - val_mean_absolute_error: 0.0209
# Epoch 26/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 0.0010 - val_mean_absolute_error: 0.0204
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 28/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.7927e-04 - val_mean_absolute_error: 0.0200
# Epoch 29/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 0.0012 - val_mean_absolute_error: 0.0225
# Epoch 30/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 0.0010 - val_mean_absolute_error: 0.0201
# Epoch 31/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 9.4786e-04 - val_mean_absolute_error: 0.0195
# Epoch 32/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 9.8536e-04 - val_mean_absolute_error: 0.0198
# Epoch 33/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 0.0010 - val_mean_absolute_error: 0.0200
# Epoch 34/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 0.0010 - val_mean_absolute_error: 0.0205
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0205

# %%
mo_cnn_lstm_model = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), activation='relu'),
    LSTM(32, return_sequences=True),
    Dense(units=2)
])

history = compile_and_fit(mo_cnn_lstm_model, wide_mo_conv_window)

mo_val_performance['CNN + LSTM'] = mo_cnn_model.evaluate(wide_mo_conv_window.val)
mo_performance['CNN + LSTM'] = mo_cnn_model.evaluate(wide_mo_conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 11s 24ms/step - loss: 0.0229 - mean_absolute_error: 0.0914 - val_loss: 0.0041 - val_mean_absolute_error: 0.0419
# Epoch 2/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0031 - mean_absolute_error: 0.0362 - val_loss: 0.0022 - val_mean_absolute_error: 0.0319
# Epoch 3/50
# 384/384 [==============================] - 8s 20ms/step - loss: 0.0022 - mean_absolute_error: 0.0303 - val_loss: 0.0017 - val_mean_absolute_error: 0.0280
# Epoch 4/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0019 - mean_absolute_error: 0.0276 - val_loss: 0.0016 - val_mean_absolute_error: 0.0271
# Epoch 5/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0018 - mean_absolute_error: 0.0263 - val_loss: 0.0015 - val_mean_absolute_error: 0.0274
# Epoch 6/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0016 - mean_absolute_error: 0.0253 - val_loss: 0.0013 - val_mean_absolute_error: 0.0240
# Epoch 7/50
# 384/384 [==============================] - 10s 27ms/step - loss: 0.0016 - mean_absolute_error: 0.0245 - val_loss: 0.0013 - val_mean_absolute_error: 0.0243
# Epoch 8/50
# 384/384 [==============================] - 12s 30ms/step - loss: 0.0015 - mean_absolute_error: 0.0239 - val_loss: 0.0012 - val_mean_absolute_error: 0.0234
# Epoch 9/50
# 384/384 [==============================] - 15s 39ms/step - loss: 0.0015 - mean_absolute_error: 0.0234 - val_loss: 0.0012 - val_mean_absolute_error: 0.0235
# Epoch 10/50
# 384/384 [==============================] - 12s 31ms/step - loss: 0.0014 - mean_absolute_error: 0.0232 - val_loss: 0.0011 - val_mean_absolute_error: 0.0221
# Epoch 11/50
# 384/384 [==============================] - 11s 28ms/step - loss: 0.0014 - mean_absolute_error: 0.0227 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 12/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0014 - mean_absolute_error: 0.0225 - val_loss: 0.0011 - val_mean_absolute_error: 0.0214
# Epoch 13/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0014 - mean_absolute_error: 0.0224 - val_loss: 0.0011 - val_mean_absolute_error: 0.0215
# Epoch 14/50
# 384/384 [==============================] - 8s 22ms/step - loss: 0.0013 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0214
# Epoch 15/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0013 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0217
# Epoch 16/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0013 - mean_absolute_error: 0.0217 - val_loss: 0.0011 - val_mean_absolute_error: 0.0212
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0205

# %%
wide_mo_conv_window.plot(mo_cnn_lstm_model)

# %%
mo_mae_val.extend([v[1] for v in mo_val_performance.values()])
mo_mae_test.extend([v[1] for v in mo_performance.values()])

x = np.arange(6)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.001, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.001, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH16_F08_peixeiro.png', dpi=300)
