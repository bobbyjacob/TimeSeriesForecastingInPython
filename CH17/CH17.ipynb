# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-04-03 12:32:47.209412: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %%
print(tf.__version__)
# Out:
# 2.11.1

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('../data/train.csv', index_col=0)
val_df = pd.read_csv('../data/val.csv', index_col=0)
test_df = pd.read_csv('../data/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift, 
                 train_df=train_df, val_df=val_df, test_df=test_df, 
                 label_columns=None):
        
        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df
        
        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}
        
        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift
        
        self.total_window_size = input_width + shift
        
        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]
        
        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
    
    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])
        
        return inputs, labels
    
    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch
        
        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))
        
        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)

            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
        
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
        
        ds = ds.map(self.split_to_inputs_labels)
        return ds
    
    @property
    def train(self):
        return self.make_dataset(self.train_df)
    
    @property
    def val(self):
        return self.make_dataset(self.val_df)
    
    @property
    def test(self):
        return self.make_dataset(self.test_df)
    
    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')
    
    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])
    
    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])
    
    return history

# %%
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# %% [markdown]
# ## Autoregressive LSTM

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %%
# Values obtained from chapter 16

ms_mae_val = [0.352, 0.347, 0.088, 0.078, 0.070, 0.078, 0.069]
ms_mae_test = [0.347, 0.341, 0.076, 0.064, 0.058, 0.063, 0.055]

# %%
class AutoRegressive(Model):
    def __init__(self, units, out_steps):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = LSTMCell(units)
        self.lstm_rnn = RNN(self.lstm_cell, return_state=True)
        self.dense = Dense(train_df.shape[1])
        
    def warmup(self, inputs):
        x, *state = self.lstm_rnn(inputs)
        prediction = self.dense(x)
                
        return prediction, state
    
    def call(self, inputs, training=None):
        predictions = []
        prediction, state = self.warmup(inputs)
        
        predictions.append(prediction)
        
        for n in range(1, self.out_steps):
            x = prediction
            x, state = self.lstm_cell(x, states=state, training=training)
            
            prediction = self.dense(x)
            predictions.append(prediction)
        
        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        
        return predictions

# %%
AR_LSTM = AutoRegressive(units=32, out_steps=24)

history = compile_and_fit(AR_LSTM, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.val)
ms_performance['AR - LSTM'] = AR_LSTM.evaluate(multi_window.test, verbose=0)
# Out:
# 2023-04-03 12:36:35.092988: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 383/383 [==============================] - 34s 59ms/step - loss: 0.0459 - mean_absolute_error: 0.1611 - val_loss: 0.0192 - val_mean_absolute_error: 0.0998
# Epoch 2/50
# 383/383 [==============================] - 20s 52ms/step - loss: 0.0162 - mean_absolute_error: 0.0904 - val_loss: 0.0171 - val_mean_absolute_error: 0.0924
# Epoch 3/50
# 383/383 [==============================] - 20s 53ms/step - loss: 0.0151 - mean_absolute_error: 0.0860 - val_loss: 0.0165 - val_mean_absolute_error: 0.0900
# Epoch 4/50
# 383/383 [==============================] - 23s 59ms/step - loss: 0.0147 - mean_absolute_error: 0.0841 - val_loss: 0.0166 - val_mean_absolute_error: 0.0903
# Epoch 5/50
# 383/383 [==============================] - 28s 72ms/step - loss: 0.0145 - mean_absolute_error: 0.0830 - val_loss: 0.0162 - val_mean_absolute_error: 0.0895
# Epoch 6/50
# 383/383 [==============================] - 22s 58ms/step - loss: 0.0141 - mean_absolute_error: 0.0813 - val_loss: 0.0160 - val_mean_absolute_error: 0.0882
# Epoch 7/50
# 383/383 [==============================] - 20s 51ms/step - loss: 0.0138 - mean_absolute_error: 0.0800 - val_loss: 0.0159 - val_mean_absolute_error: 0.0879
# Epoch 8/50
# 383/383 [==============================] - 22s 56ms/step - loss: 0.0134 - mean_absolute_error: 0.0786 - val_loss: 0.0148 - val_mean_absolute_error: 0.0799
# Epoch 9/50
# 383/383 [==============================] - 21s 55ms/step - loss: 0.0131 - mean_absolute_error: 0.0776 - val_loss: 0.0143 - val_mean_absolute_error: 0.0790
# Epoch 10/50
# 383/383 [==============================] - 21s 54ms/step - loss: 0.0127 - mean_absolute_error: 0.0763 - val_loss: 0.0145 - val_mean_absolute_error: 0.0804
# Epoch 11/50
# 383/383 [==============================] - 19s 49ms/step - loss: 0.0121 - mean_absolute_error: 0.0743 - val_loss: 0.0139 - val_mean_absolute_error: 0.0810
# Epoch 12/50
# 383/383 [==============================] - 19s 49ms/step - loss: 0.0116 - mean_absolute_error: 0.0723 - val_loss: 0.0128 - val_mean_absolute_error: 0.0764
# Epoch 13/50
# 383/383 [==============================] - 20s 53ms/step - loss: 0.0110 - mean_absolute_error: 0.0699 - val_loss: 0.0121 - val_mean_absolute_error: 0.0717
# Epoch 14/50
# 383/383 [==============================] - 26s 68ms/step - loss: 0.0105 - mean_absolute_error: 0.0681 - val_loss: 0.0116 - val_mean_absolute_error: 0.0699
# Epoch 15/50
# 383/383 [==============================] - 30s 79ms/step - loss: 0.0099 - mean_absolute_error: 0.0657 - val_loss: 0.0119 - val_mean_absolute_error: 0.0702
# Epoch 16/50
# 383/383 [==============================] - 25s 65ms/step - loss: 0.0095 - mean_absolute_error: 0.0643 - val_loss: 0.0115 - val_mean_absolute_error: 0.0726
# Epoch 17/50
# 383/383 [==============================] - 22s 57ms/step - loss: 0.0094 - mean_absolute_error: 0.0636 - val_loss: 0.0119 - val_mean_absolute_error: 0.0724
# Epoch 18/50
# 383/383 [==============================] - 26s 67ms/step - loss: 0.0092 - mean_absolute_error: 0.0630 - val_loss: 0.0107 - val_mean_absolute_error: 0.0643
# Epoch 19/50
# 383/383 [==============================] - 24s 62ms/step - loss: 0.0089 - mean_absolute_error: 0.0615 - val_loss: 0.0101 - val_mean_absolute_error: 0.0649
# Epoch 20/50
# 383/383 [==============================] - 22s 57ms/step - loss: 0.0087 - mean_absolute_error: 0.0607 - val_loss: 0.0117 - val_mean_absolute_error: 0.0691
# Epoch 21/50
# 383/383 [==============================] - 24s 62ms/step - loss: 0.0086 - mean_absolute_error: 0.0605 - val_loss: 0.0099 - val_mean_absolute_error: 0.0622
# Epoch 22/50
# 383/383 [==============================] - 25s 65ms/step - loss: 0.0084 - mean_absolute_error: 0.0595 - val_loss: 0.0096 - val_mean_absolute_error: 0.0629
# Epoch 23/50
# 383/383 [==============================] - 25s 65ms/step - loss: 0.0084 - mean_absolute_error: 0.0597 - val_loss: 0.0099 - val_mean_absolute_error: 0.0634
# Epoch 24/50
# 383/383 [==============================] - 24s 62ms/step - loss: 0.0081 - mean_absolute_error: 0.0583 - val_loss: 0.0100 - val_mean_absolute_error: 0.0603
# Epoch 25/50
# 383/383 [==============================] - 29s 74ms/step - loss: 0.0080 - mean_absolute_error: 0.0576 - val_loss: 0.0090 - val_mean_absolute_error: 0.0609
# Epoch 26/50
# 383/383 [==============================] - 25s 64ms/step - loss: 0.0077 - mean_absolute_error: 0.0566 - val_loss: 0.0089 - val_mean_absolute_error: 0.0568
# Epoch 27/50
# 383/383 [==============================] - 39s 102ms/step - loss: 0.0077 - mean_absolute_error: 0.0566 - val_loss: 0.0102 - val_mean_absolute_error: 0.0663
# Epoch 28/50
# 383/383 [==============================] - 32s 82ms/step - loss: 0.0075 - mean_absolute_error: 0.0554 - val_loss: 0.0088 - val_mean_absolute_error: 0.0607
# Epoch 29/50
# 383/383 [==============================] - 22s 57ms/step - loss: 0.0074 - mean_absolute_error: 0.0552 - val_loss: 0.0087 - val_mean_absolute_error: 0.0562
# Epoch 30/50
# 383/383 [==============================] - 22s 57ms/step - loss: 0.0071 - mean_absolute_error: 0.0537 - val_loss: 0.0085 - val_mean_absolute_error: 0.0566
# Epoch 31/50
# 383/383 [==============================] - 20s 51ms/step - loss: 0.0069 - mean_absolute_error: 0.0530 - val_loss: 0.0083 - val_mean_absolute_error: 0.0556
# Epoch 32/50
# 383/383 [==============================] - 20s 53ms/step - loss: 0.0069 - mean_absolute_error: 0.0529 - val_loss: 0.0080 - val_mean_absolute_error: 0.0532
# Epoch 33/50
# 383/383 [==============================] - 20s 51ms/step - loss: 0.0067 - mean_absolute_error: 0.0523 - val_loss: 0.0083 - val_mean_absolute_error: 0.0540
# Epoch 34/50
# 383/383 [==============================] - 25s 65ms/step - loss: 0.0066 - mean_absolute_error: 0.0515 - val_loss: 0.0080 - val_mean_absolute_error: 0.0548
# Epoch 35/50
# 383/383 [==============================] - 28s 72ms/step - loss: 0.0065 - mean_absolute_error: 0.0511 - val_loss: 0.0079 - val_mean_absolute_error: 0.0542
# Epoch 36/50
# 383/383 [==============================] - 27s 71ms/step - loss: 0.0064 - mean_absolute_error: 0.0507 - val_loss: 0.0077 - val_mean_absolute_error: 0.0531
# Epoch 37/50
# 383/383 [==============================] - 22s 58ms/step - loss: 0.0064 - mean_absolute_error: 0.0505 - val_loss: 0.0086 - val_mean_absolute_error: 0.0530
# Epoch 38/50
# 383/383 [==============================] - 21s 55ms/step - loss: 0.0062 - mean_absolute_error: 0.0498 - val_loss: 0.0075 - val_mean_absolute_error: 0.0539
# Epoch 39/50
# 383/383 [==============================] - 17s 43ms/step - loss: 0.0063 - mean_absolute_error: 0.0503 - val_loss: 0.0077 - val_mean_absolute_error: 0.0557
# Epoch 40/50
# 383/383 [==============================] - 20s 52ms/step - loss: 0.0062 - mean_absolute_error: 0.0494 - val_loss: 0.0076 - val_mean_absolute_error: 0.0515
# Epoch 41/50
# 383/383 [==============================] - 18s 47ms/step - loss: 0.0062 - mean_absolute_error: 0.0496 - val_loss: 0.0082 - val_mean_absolute_error: 0.0570
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0082 - mean_absolute_error: 0.0570

# %%
multi_window.plot(AR_LSTM)

plt.savefig('figures/CH17_F03_peixeiro.png', dpi=300)

# %%
ms_mae_val.append(ms_val_performance['AR - LSTM'][1])
ms_mae_test.append(ms_performance['AR - LSTM'][1])

x = np.arange(8)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM', 'AR - LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.18, ms_mae_val, width=0.3, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.18, ms_mae_test, width=0.3, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.18, y=value+0.0025, s=str(round(value, 3)), ha='center')
    
for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.18, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures/CH17_F04_peixeiro.png', dpi=300)
